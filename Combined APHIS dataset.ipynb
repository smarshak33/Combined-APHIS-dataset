# %%
## need to import libraries, csvs, make sure they are standardized, merge them, and download the new csv

# %%
import pandas as pd

# %%
df_species = pd.read_csv(class-demos/"inspections.csv")
df_species.head()
# Out:
#   Cell In[4], line 1
#     df_species = pd.read_csv(class-demos/"inspections.csv")
#                              ^
# SyntaxError: invalid syntax
